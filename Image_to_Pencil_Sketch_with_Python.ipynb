# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishekkharade/LGMVIP-DataScience-Task2/blob/main/Image_to_Pencil_Sketch_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name: Abhishek Kharade
#
# **Image to Pencil Sketch with Python**

# %%
import cv2
from IPython.display import Image
from google.colab.patches import cv2_imshow

# %% [markdown]
# **Load image**

# %%
image = cv2.imread("/content/dog.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=202x250 at 0x7F110CAF5A10>

# %% [markdown]
# **Greyscale**

# %%
gray_image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=202x250 at 0x7F110CA93710>

# %% [markdown]
# **Invert image**

# %%
inverted_image = 255 - gray_image
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=202x250 at 0x7F110CA9D450>

# %% [markdown]
# **Blur Image**

# %%
blurred = cv2.GaussianBlur(inverted_image,(21,21),0)
cv2_imshow(blurred)
# Out:
# <PIL.Image.Image image mode=L size=202x250 at 0x7F110CA9DD50>

# %%
inverted_blurred = 255 - blurred
cv2_imshow(inverted_blurred)
# Out:
# <PIL.Image.Image image mode=L size=202x250 at 0x7F110CA88E10>

# %%
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=202x250 at 0x7F110CA93450>
